# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 6</b></center>
# <center><b><h4>Roll No. : 369</b></center>
# <center><b><h4>Name : Kalola Hill</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to find sum of all the elements in a List.

# %%
l = map(int, input("enter a list").split(" "))
total = 0
for i in l:
    total = total + i
print (total)
# Out:
# enter a list 1 2 3 4 5 6
# 21

# %% [markdown]
# ### 02) WAP to find largest element in a List.

# %%
l = list(map(int, input("enter a list").split(" ")))
maxEle = l[0]
for i in l:
    if i > maxEle:
        maxEle = i
print(maxEle)
# Out:
# enter a list 1 3225 45 3 45 23
# 3225

# %% [markdown]
# ### 03) WAP to find the length of a List.

# %%
l = list(map(int, input("enter a list").split(" ")))
listLen = len(l)
print (listLen)
# Out:
# enter a list 1 3 5 63 7 3 46 246
# 8

# %% [markdown]
# ### 04) WAP to interchange first and last elements in a list.

# %%
l = list(map(int, input("enter a list").split(" ")))
temp = l[0]
l[0] = l[-1]
l[-1] = temp

print(l)
# Out:
# enter a list 1 23 34346 45 74576
# [74576, 23, 34346, 45, 1]

# %% [markdown]
# ### 05) WAP to split the List into two parts and append the first part to the end.

# %%
l = list(map(int, input("enter a list").split(" ")))
splitIdx = len(l) // 2 
first = l[:splitIdx]
second = l[splitIdx:] 
l2 = second + first
print(l2)
# Out:
# enter a list 1 2 3 4 5 6
# [4, 5, 6, 1, 2, 3]

# %% [markdown]
# ### 06) WAP to interchange the elements on two positions entered by a user.

# %%
l = list(map(int, input("enter a list").split(" ")))
p1 = int(input("enter first position"))
p2 = int(input("enter second position"))

temp = l[p1]
l[p1] = l[p2]
l[p2] = temp

print(l)
# Out:
# enter a list 1 2 4 5 622 5 2 123 52
# enter first position 2
# enter second position 5
# [1, 2, 5, 5, 622, 4, 2, 123, 52]

# %% [markdown]
# ### 07) WAP to reverse the list entered by user.

# %%
l = list(map(int, input("enter a list").split(" ")))
l.reverse()
print(l)
# Out:
# enter a list 1 3 5 62 5 25 23
# [23, 25, 5, 62, 5, 3, 1]

# %% [markdown]
# ### 08) WAP to print even numbers in a list.

# %%
l = list(map(int, input("enter a list").split(" ")))
ans = [i for i in l if i%2==0]
print(ans)
# Out:
# enter a list 1 2 4 5 63 22 36 8 6
# [2, 4, 22, 36, 8, 6]

# %% [markdown]
# ### 09) WAP to count unique items in a list.

# %%
l = list(map(int, input("enter a list").split(" ")))
unique_items = []

for item in l:
    if item not in unique_items:
        unique_items.append(item)

print(f"Unique items count: {len(unique_items)}")
# Out:
# enter a list 1 2 3 2 3 2 1 3 2 4 2 4
# Unique items count: 4

# %% [markdown]
# ### 10) WAP to copy a list.

# %%
l = list(map(int, input("enter a list").split(" ")))
l1 = l.copy()
print(l1)
# Out:
# enter a list 1 2 3 2 2 3 2 46 4
# [1, 2, 3, 2, 2, 3, 2, 46, 4]

# %% [markdown]
# ### 11) WAP to print all odd numbers in a given range.

# %%
l = list(map(int, input("enter a list").split(" ")))
p1 = int(input("enter first position"))
p2 = int(input("enter second position"))

for number in range(p1, p2):
    if number % 2 != 0:
        print(number)
# Out:
# enter a list 12 3 4 3 5 3 2 2 4 5 67 7 7
# enter first position 2
# enter second position 6
# 3
# 5

# %% [markdown]
# ### 12) WAP to count occurrences of an element in a list.

# %%
l = list(map(int, input("enter a list").split(" ")))
element_to_count = 1

count = 0
for item in l:
    if item == element_to_count:
        count += 1

print(count)
# Out:
# enter a list 1 2 3 1 2 1 1 12 3 23 2
# 4

# %% [markdown]
# ### 13) WAP to find second largest number in a list.

# %%
user_input = input("Enter a list of numbers separated by spaces: ").split()

if not user_input:
    print("The list is empty.")
else:
    l = [int(x) for x in user_input]

    largest = second_largest = float('-inf')

    for num in l:
        if num > largest:
            second_largest = largest
            largest = num
        elif num > second_largest and num != largest:
            second_largest = num

    if second_largest == float('-inf'):  #-inf is negative infinity
        print("There is no second largest number (all numbers might be the same).")
    else:
        print("The second largest number is:", second_largest)
# Out:
# enter a list 1 2 3 3 2 4 2 4
# The second largest number is: 3

# %% [markdown]
# ### 14) WAP to extract elements with frequency greater than K.

# %%
l = list(map(int, input("enter a list").split(" ")))
k = int(input("enter element"))

l2=[i for i in l if l.count(i) > k]
l3 = list(set(l2))
print(l3)
# Out:
# enter a list 1 2 2 2 3 3 4 4 4 5 5
# enter element 1
# [2, 3, 4, 5]

# %% [markdown]
# ### 15) WAP to create a list of squared numbers from 0 to 9 with and without using List Comprehension.

# %%
l = list(map(int, input("enter a list").split(" ")))
l2=[]

for i in l:
    l2.append(i**2)
print(l2)
# Out:
# enter a list 1 2 3 4 5
# [1, 4, 9, 16, 25]

# %% [markdown]
# ### 16) WAP to create a new list (fruit whose name starts with 'b') from the list of fruits given by user.

# %%
fruit = input("enter a fruit : ").split()

result = []
for i in fruit:
    if i.lower().startswith('b'):
        result.append(i)
print(result)
# Out:
# enter a fruit :  banana, apple, pinapple, barries
# ['banana,', 'barries']

# %% [markdown]
# ### 17) WAP to create a list of common elements from given two lists.

# %%
l1 = list(map(int, input("Enter first list : ").split(" ")))
l2 = list(map(int, input("Enter second list : ").split(" ")))

common = []
for i in l1:
    if i in l2 and i not in common:
        common.append(i)

print("Common elements:", common)
# Out:
# Enter first list (space-separated):  1 2 1 3 4
# Enter second list (space-separated):  1 2 1
# Common elements: [1, 2]
